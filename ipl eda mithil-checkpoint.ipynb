# %% [markdown]
# # IPL DATA ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the data
df1=pd.read_csv("C:\mithil\deliveries.csv")
df1.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
# Reading the data
df=pd.read_csv("C:\mithil\matches.csv")
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.shape
df.info()
df.describe()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
# Cleaning the data

df.isnull().sum()
df.isnull().sum().sum()
# Out:
# 656

# %%
# Removing duplicate values

df.duplicated().sum()
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
# Statistical information of the data

df.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
# 1. Total number of innings of the matches played

df1['inning'].value_counts()
# Out:
# 1    92742
# 2    86240
# 3       50
# 4       38
# 5        8
# Name: inning, dtype: int64

# %%
# 2. How many IPL seasons are we using to analyse ?

df['season'].nunique()
# Out:
# 12

# %%
# 3. Total number of matches played according to the dataset

df['id'].count()
# Out:
# 756

# %%
# 4. Which IPL team won by maximum runs?

df.loc[df['win_by_runs'].idxmax()]['winner']
# Out:
# 'Mumbai Indians'

# %%
# 5. Which IPL team won by minimum runs ?

df.loc[df['win_by_runs'].idxmin()]['winner']
# Out:
# 'Rising Pune Supergiant'

# %%
# 6. Which IPL team won by consuming maximum wickets?

df.loc[df['win_by_wickets'].idxmax()]['winner']
# Out:
# 'Kolkata Knight Riders'

# %%
# 7. Which IPL team won by consuming minimum wickets?

df.loc[df['win_by_wickets'].idxmin()]['winner']
# Out:
# 'Sunrisers Hyderabad'

# %%
# 8. Which season consisted of the highest number of matches ever played ?
season_counts = df['season'].value_counts().head(12)

# Plot the number of matches played by season
plt.figure(figsize=(10, 6))
sns.barplot(x=season_counts.index, y=season_counts.values)
plt.title('Number of Matches Played by Season',fontsize=20)
plt.show()

# %%
# 24. Which is the most successful IPL team with all the data at hand?

team_wins = df['winner'].value_counts().head(10)

# Get the most successful team
most_successful_team = team_wins.idxmax()

# Create a pie chart for the most successful team
plt.figure(figsize=(8, 8))
plt.pie(team_wins, labels=team_wins.index, autopct='%2.1f%%')
plt.title('Most Successful IPL Team',fontsize=20)
plt.legend(title='Team', labels=[most_successful_team], loc='best')
plt.show()

# %%
# 24. Which is the most successful IPL team with all the data at hand?

# Get the number of wins for each team
team_wins = matches_df['winner'].value_counts().head()

# Plot the number of wins for each team
plt.figure(figsize=(12, 2))
sns.barplot(x=team_wins.index, y=team_wins.values)
plt.title('Number of Wins by Team', fontsize =20)
plt.show()

# %%
#Top players of winning matches

top_players = matches_df['player_of_match'].value_counts().head(10)

# Plot the top 10 players with the most runs in winning matches
plt.figure(figsize=(15, 2))
sns.barplot(x=top_players.index, y=top_players.values)
plt.title('Top 10 Players with the Most Runs in Winning Matches',fontsize =15)
plt.show()

# %%
# 26. Matches according to venue

matches_venue = matches_df['venue'].value_counts().head()

# Plot the number of matches played by venue
plt.figure(figsize=(15, 6))
sns.barplot(x=matches_venue.index, y= matches_venue.values)
plt.title('Matches Played by Venue',fontsize=30)
plt.show()

# %%
# 27. The number of matches played by each team

# Combine both 'team1' and 'team2' columns to get all teams in each match
all_teams = pd.concat([df['team1'], df['team2']])

# Get the number of matches played by each team
team_counts = all_teams.value_counts().head()

# Plot the number of matches played by each team
plt.figure(figsize=(12, 6))
sns.barplot(x=team_counts.index, y=team_counts.values)
plt.title('Number of Matches Played by Each Team')
plt.xlabel('Team')
plt.ylabel('Number of Matches')
plt.xticks(rotation=0)
plt.show()

# %%
# 28. The winners in each Season

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'matches.csv' is the CSV file containing the IPL match data
df = pd.read_csv('matches.csv')

# Get the count of matches won by each team in each season
season_winner_counts = df.groupby(['season', 'winner'])['id'].count().reset_index()

# Pivot the data to create a matrix for stacked bar chart
winner_matrix = season_winner_counts.pivot('season', 'winner', 'id').fillna(0)

# Create a stacked bar chart
plt.figure(figsize=(12, 6))
winner_matrix.plot(kind='bar', stacked=True, colormap='Paired')
plt.title('Number of Matches Won by Each Team in Each Season')
plt.xlabel('Season')
plt.ylabel('Number of Matches Won')
plt.legend(title='Winner', bbox_to_anchor=(1, 1))
plt.xticks(rotation=45)
plt.show()

# %%
# 29. IPL Finals venues and winners along with the number of wins.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'matches.csv' is the CSV file containing the IPL match data
df = pd.read_csv('matches.csv')

# Get the count of matches won by each team at each venue
matches_won_at_venue = df.groupby(['venue', 'winner'])['id'].count().reset_index().head(50)

# Pivot the data to create a matrix for stacked bar chart
matches_won_matrix = matches_won_at_venue.pivot('venue', 'winner', 'id').fillna(0)

# Create a stacked bar chart
plt.figure(figsize=(12, 8))
matches_won_matrix.plot(kind='bar', stacked=True, colormap='tab20')
plt.title('Number of Matches Won by Each Team at Each Venue')
plt.xlabel('Venue')
plt.ylabel('Number of Matches Won')
plt.xticks(rotation=90)
plt.legend(title='Winner', bbox_to_anchor=(1, 1))
plt.show()

# %%
# 29. IPL Finals venues and winners along with the number of wins.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'matches.csv' is the CSV file containing the IPL match data
df = pd.read_csv('matches.csv')

# Get the count of matches won by each team at each venue
venue_winner_counts = df.groupby(['venue', 'winner'])['id'].count().reset_index()

# Create a grouped bar chart
plt.figure(figsize=(20, 12))
sns.barplot(x='venue', y='id', hue='winner', data=venue_winner_counts)
plt.title('Number of Matches Won by Each Team at Each Venue')
plt.xlabel('Venue')
plt.ylabel('Number of Matches Won')
plt.xticks(rotation=90)
plt.legend(title='Winner', bbox_to_anchor=(1, 1))
plt.show()

# %%
# 30. The number of seasons won by each team

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'matches.csv' is the CSV file containing the IPL match data
df = pd.read_csv('matches.csv')

# Get the count of matches won by each team in each season
team_season_wins = df.groupby(['winner', 'season'])['id'].count().reset_index()

# Create a grouped bar chart
plt.figure(figsize=(20, 8))
sns.barplot(x='season', y='id', hue='winner', data=team_season_wins)
plt.title('Number of Matches Won by Each Team in Each Season')
plt.xlabel('Season')
plt.ylabel('Number of Matches Won')
plt.legend(title='Team', bbox_to_anchor=(1, 1))
plt.xticks(rotation=45)
plt.show()

# %%
# 31. The toss winner, toss decision, winner in final matches.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'matches.csv' is the CSV file containing the IPL match data
df = pd.read_csv('matches.csv')

# Get the count of toss winners, toss decisions, and match winners
toss_info = df.groupby(['toss_winner', 'toss_decision', 'winner'])['id'].count().reset_index()

# Create a grouped bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x='toss_winner', y='id', hue='toss_decision', data=toss_info, ci=None)
sns.barplot(x='toss_winner', y='id', hue='winner', data=toss_info, ci=None, alpha=0.7)
plt.title('Toss Winner, Decision, and Match Winner')
plt.xlabel('Toss Winner')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Toss Decision', bbox_to_anchor=(1, 1))
plt.show()

# %%
# 32. The man of the match for each winning team

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'matches.csv' is the CSV file containing the IPL match data
df = pd.read_csv('matches.csv')

# Get the count of matches won by each team in each season
man_of_match_info = df.groupby(['winner', 'player_of_match'])['id'].count().reset_index()

# Pivot the data to create a matrix for heatmap
man_of_match_matrix = man_of_match_info.pivot('winner', 'player_of_match', 'id').fillna(0)

# Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(man_of_match_matrix, cmap='YlGnBu', annot=True, fmt='g', linewidths=0.5)
plt.title('Number of Times Each Player Became Man of the Match for Each Winning Team',fontsize=19)
plt.xlabel('Player of the Match')
plt.ylabel('Winning Team')
plt.xticks(rotation=90)
plt.show()

# %%
# 33. Decision in every toss either fielding or batting

df['toss_decision'].value_counts()

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'matches.csv' is the CSV file containing the IPL match data
df = pd.read_csv('matches.csv')

# Count the number of times each toss decision was made
toss_decision_count = df['toss_decision'].value_counts()

# Create a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=toss_decision_count.index, y=toss_decision_count.values, palette='Set2')
plt.title('Toss Decision in IPL Matches')
plt.xlabel('Toss Decision')
plt.ylabel('Count')
plt.show()

# %%
# 34. What is the probability of winning a match if the toss was won?

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'matches.csv' is the CSV file containing the IPL match data
df = pd.read_csv('matches.csv')

# Check if toss winner is the same as the match winner
df['toss_match_winner'] = df['toss_winner'] == df['winner']

# Create a countplot for visualization
plt.figure(figsize=(8, 6))
sns.countplot(x='toss_match_winner', data=df)
plt.title('Matches where Toss Winner is the Same as Match Winner')
plt.xlabel('Toss Winner Same as Match Winner')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'])
plt.show()

# %%
# 35. The top 10 leading run scorers in IPL

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'matches.csv' is the CSV file containing the IPL match data
df1=pd.read_csv("C:/Users/ayush/Desktop/deliveries.csv")

# Get the top 10 leading run scorers in IPL
top_10_run_scorers = df1.groupby(['batsman'])['batsman_runs'].sum().sort_values(ascending=False).head(10)

# Create a bar plot
plt.figure(figsize=(8, 4))
sns.barplot(x=top_10_run_scorers.index, y=top_10_run_scorers.values, palette='viridis')
plt.title('Top 10 Leading Run Scorers in IPL')
plt.xlabel('Player')
plt.ylabel('Total Runs')
plt.xticks(rotation=90)
plt.show()
